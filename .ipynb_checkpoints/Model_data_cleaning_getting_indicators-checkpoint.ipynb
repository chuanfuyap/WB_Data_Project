# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
import dill

# %% [markdown]
# # Contents
# * [Cleaning Economy](#economy)
# * [Cleaning Health](#health)
# * [Cleaning Education](#education)
# * [Cleaning Development](#development)
# * [Cleaning Finance](#finance)
# * [Cleaning Environment](#environment)
# * [Cleaning Poverty](#poverty)
#
# * [Stacks](#stacks)
# * [Train Stacks](#trainstacks)

# %%
def unwrap(indicator_name, compiled_df):
    df_index = compiled_df.at['Coverage_Range', indicator_name]
    df_index = string_to_list(df_index)
    df_index = [ind for ind in df_index if len(ind)==4]
    df_index = pd.to_datetime(df_index)
    countries = compiled_df.index
    countries = countries.drop('Coverage_Range')
    data = {}
    for country in countries:
        annual_data = compiled_df.at[country,indicator_name]
        
        if not pd.isnull(annual_data):
            time_series = string_to_list(annual_data)
            if len(time_series)==len(df_index):            
            #print country
                data[country]=time_series
            #print len(time_series), country, len(df_index)
        else:
            data[country]=np.nan
    unwrapping = pd.DataFrame(index=df_index, data=data, dtype=np.dtype(float) )
    return unwrapping
def string_to_list(string):
    list_ = string[1:-1]
    list_ = list_.split(',')
    list_ = [t.replace("'", '').strip() for t in list_]
    return list_
def data_to_list(string):
    list_ = string[1:-1]
    list_ = list_.split(',')
    list_ = [t.replace("'", '').strip() for t in list_]
    list_ = [float(t) for t in list_ if t != 'nan']
    list_ = [np.nan for t in list_ if t == 'nan']
    
    return list_

# %% [markdown]
# ## Cleaning Economy <a class="anchor" id="economy"></a>

# %%
econ = pd.read_csv('Economy.csv', index_col=0)

# %%
page = requests.get('https://data.worldbank.org/indicator?tab=all')

# %%
soup4 = BeautifulSoup(page.text,'lxml')

# %%
def get_names(bsoup, react_id):
    chart = bsoup.find_all('ul',attrs={'data-reactid':'{}'.format(react_id)})
    s_list = chart[0].find_all('li')
    indicators = [attr.text for attr in s_list]
    return indicators

# %%
econ_ind = get_names(soup4, '599')

# %%
len(econ_ind)
# Out:
# 261

# %%
econ_ind.remove(u'Portfolio Investment, net (BoP, current US$)')

# %%
econ_clean = econ[econ_ind]

# %%
econ_clean.shape
# Out:
# (346, 260)

# %%
econ_clean.head()
# Out:
#                         2005 PPP conversion factor, GDP (LCU per international $)  \
# Coverage_Range           ['1960', '1961', '1962', '1963', '1964', '1965...
# Canada                   [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# EMDE ECA South Caucasus                                                NaN
# OECD members             [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# Swaziland                [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
#
#                         2005 PPP conversion factor, private consumption (LCU per international $)  \
# Coverage_Range           ['1960', '1961', '1962', '1963', '1964', '1965...
# Canada                   [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# EMDE ECA South Caucasus                                                NaN
# OECD members             [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# Swaziland                [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
#
#                             Adjusted net national income (annual % growth)  \
# Coverage_Range           ['1960', '1961', '1962', '1963', '1964', '1965...
# Canada                   [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# EMDE ECA South Caucasus                                                NaN
# OECD members             [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# Swaziland                [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
#
#                           Adjusted net national income (constant 2010 US$)  \
# Coverage_Range           ['1960', '1961', '1962', '1963', '1964', '1965...
# Canada                   [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# EMDE ECA South Caucasus                                                NaN
# OECD members             [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# Swaziland                [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
#
#                                 Adjusted net national income (current US$)  \
# Coverage_Range           ['1960', '1961', '1962', '1963', '1964', '1965...
# Canada                   [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# EMDE ECA South Caucasus                                                NaN
# OECD members             [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# Swaziland                [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
#
#                         Adjusted net national income per capita (annual % growth)  \
# Coverage_Range           ['1960', '1961', '1962', '1963', '1964', '1965...
# Canada                   [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# EMDE ECA South Caucasus                                                NaN
# OECD members             [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# Swaziland                [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
#
#                         Adjusted net national income per capita (constant 2010 US$)  \
# Coverage_Range           ['1960', '1961', '1962', '1963', '1964', '1965...
# Canada                   [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# EMDE ECA South Caucasus                                                NaN
# OECD members             [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# Swaziland                [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
#
#                         Adjusted net national income per capita (current US$)  \
# Coverage_Range           ['1960', '1961', '1962', '1963', '1964', '1965...
# Canada                   [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# EMDE ECA South Caucasus                                                NaN
# OECD members             [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# Swaziland                [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
#
#                         Adjusted net savings, excluding particulate emission damage (% of GNI)  \
# Coverage_Range           ['1960', '1961', '1962', '1963', '1964', '1965...
# Canada                   [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# EMDE ECA South Caucasus                                                NaN
# OECD members             [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# Swaziland                [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
#
#                         Adjusted net savings, excluding particulate emission damage (current US$)  \
# Coverage_Range           ['1960', '1961', '1962', '1963', '1964', '1965...
# Canada                   [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# EMDE ECA South Caucasus                                                NaN
# OECD members             [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# Swaziland                [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
#
#                                                ...                          \
# Coverage_Range                                 ...
# Canada                                         ...
# EMDE ECA South Caucasus                        ...
# OECD members                                   ...
# Swaziland                                      ...
#
#                                              Total debt service (% of GNI)  \
# Coverage_Range           ['1960', '1961', '1962', '1963', '1964', '1965...
# Canada                   [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# EMDE ECA South Caucasus                                                NaN
# OECD members             [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# Swaziland                [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
#
#                         Total debt service (% of exports of goods, services and primary income)  \
# Coverage_Range           ['1960', '1961', '1962', '1963', '1964', '1965...
# Canada                   [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# EMDE ECA South Caucasus                                                NaN
# OECD members             [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# Swaziland                [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
#
#                                Total reserves (includes gold, current US$)  \
# Coverage_Range           ['1960', '1961', '1962', '1963', '1964', '1965...
# Canada                   [2012986400.1272302, 2296085100.2121396, 25619...
# EMDE ECA South Caucasus                                                NaN
# OECD members             [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# Swaziland                [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
#
#                                    Total reserves minus gold (current US$)  \
# Coverage_Range           ['1960', '1961', '1962', '1963', '1964', '1965...
# Canada                   [1112520000.15252, 1345840000.21214, 185200000...
# EMDE ECA South Caucasus                                                NaN
# OECD members             [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# Swaziland                [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
#
#                                                           Trade (% of GDP)  \
# Coverage_Range           ['1960', '1961', '1962', '1963', '1964', '1965...
# Canada                   [35.101614925524395, 35.804682056991, 35.57546...
# EMDE ECA South Caucasus                                                NaN
# OECD members             [23.6192237137114, 23.4471522538317, 23.181608...
# Swaziland                [82.618569621112, 76.7906705842924, 93.5812983...
#
#                                               Trade in services (% of GDP)  \
# Coverage_Range           ['1960', '1961', '1962', '1963', '1964', '1965...
# Canada                   [6.50084104905362, 6.08834437311754, 5.8984837...
# EMDE ECA South Caucasus                                                NaN
# OECD members             [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# Swaziland                [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
#
#                             Transport services (% of service exports, BoP)  \
# Coverage_Range           ['1960', '1961', '1962', '1963', '1964', '1965...
# Canada                   [19.4005839685265, 30.5744124947817, 29.964251...
# EMDE ECA South Caucasus                                                NaN
# OECD members             [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# Swaziland                [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
#
#                             Transport services (% of service imports, BoP)  \
# Coverage_Range           ['1960', '1961', '1962', '1963', '1964', '1965...
# Canada                   [22.7608314600833, 33.8379871390855, 34.249798...
# EMDE ECA South Caucasus                                                NaN
# OECD members             [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# Swaziland                [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
#
#                                Travel services (% of service exports, BoP)  \
# Coverage_Range           ['1960', '1961', '1962', '1963', '1964', '1965...
# Canada                   [37.7990178467193, 45.793325761953895, 48.0335...
# EMDE ECA South Caucasus                                                NaN
# OECD members             [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# Swaziland                [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
#
#                                Travel services (% of service imports, BoP)
# Coverage_Range           ['1960', '1961', '1962', '1963', '1964', '1965...
# Canada                   [42.236438180705704, 36.6090458003959, 34.1302...
# EMDE ECA South Caucasus                                                NaN
# OECD members             [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# Swaziland                [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
#
# [5 rows x 260 columns]

# %%
econ_clean.loc['Coverage_Range'].unique()
# Out:
# array([ "['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017']"], dtype=object)

# %%
test_ind = unwrap(econ_clean.columns[0], econ_clean)

# %%
mean_test = test_ind.mean(axis=1)

# %%
econ_dict = {}
for col in econ_clean.columns:
    ind_df = unwrap(col,econ_clean)
    econ_dict[col]=ind_df.mean(axis=1)

# %%
econ_index = econ_dict[econ_clean.columns[0]].index

# %%
econ_df = pd.DataFrame(data=econ_dict, index=econ_index)

# %%
econ_df.dropna(axis=0, how='all', inplace=True)
econ_df.dropna(axis=1, how='all', inplace=True)

# %%
econ_df.shape
# Out:
# (57, 260)

# %%
econ_df.index
# Out:
# DatetimeIndex(['1960-01-01', '1961-01-01', '1962-01-01', '1963-01-01',
#                '1964-01-01', '1965-01-01', '1966-01-01', '1967-01-01',
#                '1968-01-01', '1969-01-01', '1970-01-01', '1971-01-01',
#                '1972-01-01', '1973-01-01', '1974-01-01', '1975-01-01',
#                '1976-01-01', '1977-01-01', '1978-01-01', '1979-01-01',
#                '1980-01-01', '1981-01-01', '1982-01-01', '1983-01-01',
#                '1984-01-01', '1985-01-01', '1986-01-01', '1987-01-01',
#                '1988-01-01', '1989-01-01', '1990-01-01', '1991-01-01',
#                '1992-01-01', '1993-01-01', '1994-01-01', '1995-01-01',
#                '1996-01-01', '1997-01-01', '1998-01-01', '1999-01-01',
#                '2000-01-01', '2001-01-01', '2002-01-01', '2003-01-01',
#                '2004-01-01', '2005-01-01', '2006-01-01', '2007-01-01',
#                '2008-01-01', '2009-01-01', '2010-01-01', '2011-01-01',
#                '2012-01-01', '2013-01-01', '2014-01-01', '2015-01-01',
#                '2016-01-01'],
#               dtype='datetime64[ns]', freq=None)

# %%
econ_clean.to_csv('ML_econ_clean.csv')

# %%
econ_df.to_csv('ML_econ_world__annual_avg.csv')

# %% [markdown]
# ## Cleaning Health <a class="anchor" id="health"></a>

# %%
health = pd.read_csv('Health.csv', index_col=0)

# %%
health_ind = get_names(soup4, '2762')

# %%
health_ind.remove('Population, ages 0-14, male')
health_ind.remove('Proportion of women subjected to physical and/or sexual violence in the last 12 months ( % of women age 15-49)')
health_ind.remove(u'Total Population for Age 65 and above (only 2005 and 2010) (in number of people)')
health_ind.remove('Population, ages 0-14, total')

# %%
health_clean = health[health_ind]

# %%
health_clean.shape
# Out:
# (2218, 217)

# %%
health_clean.loc['Coverage_Range'].unique()
# Out:
# array([ "['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017']"], dtype=object)

# %%
def make_clean_df(clean_this_df):
    temp_dict = {}
    for col in clean_this_df.columns:
        ind_df = unwrap(col,clean_this_df)
        temp_dict[col]=ind_df.mean(axis=1)
        
    temp_index = temp_dict[clean_this_df.columns[0]].index
    cleaned_df = pd.DataFrame(data=temp_dict, index=temp_index)
    cleaned_df.dropna(axis=0, how='all', inplace=True)
    cleaned_df.dropna(axis=1, how='all', inplace=True)
    return cleaned_df

# %%
health_df = make_clean_df(health_clean)

# %%
health_df.head()
# Out:
#             ARI treatment (% of children under 5 taken to a health provider)  \
# 1960-01-01                                                NaN
# 1961-01-01                                                NaN
# 1962-01-01                                                NaN
# 1963-01-01                                                NaN
# 1964-01-01                                                NaN
#
#             Adolescent fertility rate (births per 1,000 women ages 15-19)  \
# 1960-01-01                                         101.288734
# 1961-01-01                                         101.265981
# 1962-01-01                                         101.217591
# 1963-01-01                                         100.664081
# 1964-01-01                                         100.112480
#
#             Adults (ages 15+) and children (ages 0-14) newly infected with HIV  \
# 1960-01-01                                                NaN
# 1961-01-01                                                NaN
# 1962-01-01                                                NaN
# 1963-01-01                                                NaN
# 1964-01-01                                                NaN
#
#             Adults (ages 15+) newly infected with HIV  \
# 1960-01-01                                        NaN
# 1961-01-01                                        NaN
# 1962-01-01                                        NaN
# 1963-01-01                                        NaN
# 1964-01-01                                        NaN
#
#             Age dependency ratio (% of working-age population)  \
# 1960-01-01                                          78.929377
# 1961-01-01                                          79.826724
# 1962-01-01                                          80.618040
# 1963-01-01                                          81.268845
# 1964-01-01                                          81.690605
#
#             Age dependency ratio, old (% of working-age population)  \
# 1960-01-01                                           8.203312
# 1961-01-01                                           8.281940
# 1962-01-01                                           8.345378
# 1963-01-01                                           8.394246
# 1964-01-01                                           8.429127
#
#             Age dependency ratio, young (% of working-age population)  \
# 1960-01-01                                          70.739160
# 1961-01-01                                          71.560053
# 1962-01-01                                          72.288102
# 1963-01-01                                          72.888730
# 1964-01-01                                          73.274599
#
#             Antiretroviral therapy coverage (% of people living with HIV)  \
# 1960-01-01                                                NaN
# 1961-01-01                                                NaN
# 1962-01-01                                                NaN
# 1963-01-01                                                NaN
# 1964-01-01                                                NaN
#
#             Antiretroviral therapy coverage for PMTCT (% of pregnant women living with HIV)  \
# 1960-01-01                                                NaN
# 1961-01-01                                                NaN
# 1962-01-01                                                NaN
# 1963-01-01                                                NaN
# 1964-01-01                                                NaN
#
#             Birth rate, crude (per 1,000 people)  \
# 1960-01-01                             38.186931
# 1961-01-01                             37.870258
# 1962-01-01                             37.959706
# 1963-01-01                             37.878483
# 1964-01-01                             37.423920
#
#                                       ...                             \
# 1960-01-01                            ...
# 1961-01-01                            ...
# 1962-01-01                            ...
# 1963-01-01                            ...
# 1964-01-01                            ...
#
#             Vitamin A supplementation coverage rate (% of children ages 6-59 months)  \
# 1960-01-01                                                NaN
# 1961-01-01                                                NaN
# 1962-01-01                                                NaN
# 1963-01-01                                                NaN
# 1964-01-01                                                NaN
#
#             Wanted fertility rate (births per woman)  \
# 1960-01-01                                       NaN
# 1961-01-01                                       NaN
# 1962-01-01                                       NaN
# 1963-01-01                                       NaN
# 1964-01-01                                       NaN
#
#             Women who believe a husband is justified in beating his wife (any of five reasons) (%)  \
# 1960-01-01                                                NaN
# 1961-01-01                                                NaN
# 1962-01-01                                                NaN
# 1963-01-01                                                NaN
# 1964-01-01                                                NaN
#
#             Women who believe a husband is justified in beating his wife when she argues with him (%)  \
# 1960-01-01                                                NaN
# 1961-01-01                                                NaN
# 1962-01-01                                                NaN
# 1963-01-01                                                NaN
# 1964-01-01                                                NaN
#
#             Women who believe a husband is justified in beating his wife when she burns the food (%)  \
# 1960-01-01                                                NaN
# 1961-01-01                                                NaN
# 1962-01-01                                                NaN
# 1963-01-01                                                NaN
# 1964-01-01                                                NaN
#
#             Women who believe a husband is justified in beating his wife when she goes out without telling him (%)  \
# 1960-01-01                                                NaN
# 1961-01-01                                                NaN
# 1962-01-01                                                NaN
# 1963-01-01                                                NaN
# 1964-01-01                                                NaN
#
#             Women who believe a husband is justified in beating his wife when she neglects the children (%)  \
# 1960-01-01                                                NaN
# 1961-01-01                                                NaN
# 1962-01-01                                                NaN
# 1963-01-01                                                NaN
# 1964-01-01                                                NaN
#
#             Women who believe a husband is justified in beating his wife when she refuses sex with him (%)  \
# 1960-01-01                                                NaN
# 1961-01-01                                                NaN
# 1962-01-01                                                NaN
# 1963-01-01                                                NaN
# 1964-01-01                                                NaN
#
#             Women who were first married by age 18 (% of women ages 20-24)  \
# 1960-01-01                                                NaN
# 1961-01-01                                                NaN
# 1962-01-01                                                NaN
# 1963-01-01                                                NaN
# 1964-01-01                                                NaN
#
#             Women's share of population ages 15+ living with HIV (%)
# 1960-01-01                                                NaN
# 1961-01-01                                                NaN
# 1962-01-01                                                NaN
# 1963-01-01                                                NaN
# 1964-01-01                                                NaN
#
# [5 rows x 217 columns]

# %%
health_df.to_csv('ML_health_world__annual_avg.csv')
health_clean.to_csv('ML_health_clean.csv')

# %% [markdown]
# ## Cleaning Education <a class="anchor" id="education"></a>

# %%
edu = pd.read_csv('Education.csv', index_col=0)
# Out:
# /opt/conda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (7,55,132,177,180,243,266,361,458,481,578,600,610,620,629,753,794,857,873,882,974,1037,1052,1275,1610,1644,1742,1791,1816,1820,1908,1915,1972,2039,2059,2086,2112,2390,2401,2410,2452,2466,2478,2499,2505,2539,2643,2699,2885,2910,2916,2936,2991,3100,3101,3146,3191,3225,3234,3259,3317,3381,3447,3460,3487,3492,3504,3528,3628,3631,3691,3731,3759,3781,3848,3874,3965,4039,4051,4078,4094,4129,4332,4371,4431,4557,4776,4827,4926,5103,5161,5212,5229,5262,5280,5359,5389) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
edu_ind = get_names(soup4, '1128')

# %%
edu_ind.remove('Gross enrollment ratio, primary, both sexes (%)')

# %%
edu_clean = edu[edu_ind]

# %%
edu_clean.loc['Coverage_Range'].unique()[1]
# Out:
# "['1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2020', '2025', '2030', '2035', '2040', '2045', '2050', '2055', '2060', '2065', '2070', '2075', '2080', '2085', '2090', '2095', '2100']"

# %%
long_index =edu_clean.loc['Coverage_Range'].unique()[1]

# %%
edu_clean.shape
# Out:
# (287, 158)

# %%
temp = (edu_clean.loc['Coverage_Range'] == long_index)
temp2 = (edu_clean.loc['Coverage_Range'] != long_index)
long_range = edu_clean.columns[temp]
short_range = edu_clean.columns[temp2]

# %%
edu_clean1 = edu_clean[short_range]
edu_clean2 = edu_clean[long_range]

# %%
edu_df1 = make_clean_df(edu_clean1)
edu_df2 = make_clean_df(edu_clean2)

# %%
edu_df = pd.concat([edu_df1, edu_df2], axis=1)
edu_df.shape
# Out:
# (58, 158)

# %%
edu_df.to_csv('ML_edu_world__annual_avg.csv')
edu_clean.to_csv('ML_edu_clean.csv')

# %% [markdown]
# ## Cleaning Development <a class="anchor" id="development"></a>

# %%
dev = pd.read_csv('Development Indicator.csv', index_col=0)

# %%
dev_ind =  get_names(soup4, '182')
dev_ind2 =  get_names(soup4, '3209')
dev_ind3 =  get_names(soup4, '3927')
dev_ind4 =  get_names(soup4, '4647')

# %%
dev_ind.extend(dev_ind2)
dev_ind.extend(dev_ind3)
dev_ind.extend(dev_ind4)

# %%
dev_clean = dev[dev_ind]

# %%
def make_clean_df2(clean_this_df, main_df):
    temp_dict = {}
    for col in clean_this_df.columns:
        ind_df = unwrap(col,main_df)
        temp_dict[col]=ind_df.mean(axis=1)
        
    temp_index = temp_dict[clean_this_df.columns[0]].index
    cleaned_df = pd.DataFrame(data=temp_dict, index=temp_index)
    cleaned_df.dropna(axis=0, how='all', inplace=True)
    cleaned_df.dropna(axis=1, how='all', inplace=True)
    return cleaned_df

# %%
dev_df = make_clean_df2(dev_clean, dev)

# %%
dev_df.to_csv('ML_dev_world__annual_avg.csv')
dev_clean.to_csv('ML_dev_clean.csv')

# %% [markdown]
# ## Cleaning Finance <a class="anchor" id="finance"></a>

# %%
fin = pd.read_csv('Finance.csv', index_col=0)

# %%
fin_ind =  get_names(soup4, '2251')

# %%
nonsense = """Account (% age 15+)
Account at a financial institution (% age 15+) [ts]
Account at a financial institution, female (% age 15+) [ts]
Account at a financial institution, income, poorest 40% (% ages 15+) [ts]
Account at a financial institution, income, richest 60% (% ages 15+) [ts]
Account at a financial institution, male (% age 15+) [ts]
Account, female (% age 15+)
Account, income, poorest 40% (% ages 15+)
Account, income, richest 60% (% ages 15+)
Account, male (% age 15+)
Account, older adults (% ages 25+)
Account, primary education or less (% ages 15+)
Account, secondary education or more (% ages 15+)
Account, young adults (% ages 15-24)
Mobile account (% age 15+) [w2]
Mobile account, female (% age 15+) [w2]
Mobile account, income, poorest 40% (% ages 15+) [w2]
Mobile account, income, richest 60% (% ages 15+) [w2]
Mobile account, male (% age 15+) [w2]
Portfolio Investment, net (BoP, current US$)
"""

# %%
nonsense_list = nonsense.split('\n')

# %%
for non in nonsense_list:
    print non
    fin_ind.remove(non)
# Out:
# Account (% age 15+)
# Account at a financial institution (% age 15+) [ts]
# Account at a financial institution, female (% age 15+) [ts]
# Account at a financial institution, income, poorest 40% (% ages 15+) [ts]
# Account at a financial institution, income, richest 60% (% ages 15+) [ts]
# Account at a financial institution, male (% age 15+) [ts]
# Account, female (% age 15+)
# Account, income, poorest 40% (% ages 15+)
# Account, income, richest 60% (% ages 15+)
# Account, male (% age 15+)
# Account, older adults (% ages 25+)
# Account, primary education or less (% ages 15+)
# Account, secondary education or more (% ages 15+)
# Account, young adults (% ages 15-24)
# Mobile account (% age 15+) [w2]
# Mobile account, female (% age 15+) [w2]
# Mobile account, income, poorest 40% (% ages 15+) [w2]
# Mobile account, income, richest 60% (% ages 15+) [w2]
# Mobile account, male (% age 15+) [w2]
# Portfolio Investment, net (BoP, current US$)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-233-46a8d6b4ba61> in <module>()
#       1 for non in nonsense_list:
#       2     print non
# ----> 3     fin_ind.remove(non)
#
# ValueError: list.remove(x): x not in list

# %%
fin_clean = econ[fin_ind]

# %%
fin_df = make_clean_df(fin_clean)

# %%
fin_df.to_csv('ML_fin_world__annual_avg.csv')
fin_clean.to_csv('ML_fin_clean.csv')

# %% [markdown]
# ## Cleaning Environment <a class="anchor" id="environment"></a>

# %%
env = pd.read_csv('Development Indicator.csv',index_col=0)

# %%
env_ind =  get_names(soup4, '1452')
env_ind2 =  get_names(soup4, '1557')
env_ind3 =  get_names(soup4, '433')

# %%
env_ind.remove('Value lost due to electrical outages (% of sales)')

# %%
env_clean = env[env_ind]

# %%
env_df = make_clean_df(env_clean)

# %%
env_df.to_csv('ML_env_world__annual_avg.csv')
env_clean.to_csv('ML_env_clean.csv')

# %% [markdown]
# ## Cleaning Poverty <a class="anchor" id="poverty"></a>

# %%
poverty = pd.read_csv('Poverty.csv',index_col=0)

# %%
pov_ind = get_names(soup4,'3319')

# %%
pov_clean = poverty[pov_ind]

# %%
pov_df = make_clean_df(pov_clean)

# %%
pov_df.to_csv('ML_pov_world__annual_avg.csv')
pov_clean.to_csv('ML_pov_clean.csv')

# %% [markdown]
# # Making stacks  <a class="anchor" id="stacks"></a>

# %%
def string_to_list(string):
    list_ = string[1:-1]
    list_ = list_.split(',')
    list_ = [t.replace("'", '').strip() for t in list_]
    return list_

def country_unwrap_no_index(country, compiled_df):
    df_index = compiled_df.loc['Coverage_Range'].unique()[0]
    df_index = string_to_list(df_index)
    country_df = compiled_df.loc[country]
    data = {}
    for indicator, values in country_df.iteritems():
        if not pd.isnull(values):            
            time_series = string_to_list(values)
            if len(time_series)==len(df_index):
                data[indicator]=time_series
        else:
            data[indicator]=[np.nan]*len(df_index)
    unwrapping = pd.DataFrame(data=data, dtype=np.dtype(float) )
    unwrapping.interpolate()
    return unwrapping

# %%
def get_stack(cleaned_df):
    df_list = []
    country_list = cleaned_df.index.tolist()
    country_list.remove('Coverage_Range')
    for country in country_list:
        #print country
        temp_df = country_unwrap_no_index(country, cleaned_df)
        df_list.append(temp_df)
    stack_df = pd.concat(df_list).reset_index()
    stack_df.drop(columns=['index'], inplace=True)
    return stack_df

# %%
econ_clean = pd.read_csv('ML_data/ML_econ_clean.csv', index_col=0)
fin_clean =pd.read_csv('ML_data/ML_fin_clean.csv', index_col=0)

# %%
econ_clean = pd.read_csv('ML_data/ML_econ_clean.csv', index_col=0)
fin_clean =pd.read_csv('ML_data/ML_fin_clean.csv', index_col=0)
health_clean =pd.read_csv('ML_data/ML_health_clean.csv', index_col=0)
dev_clean =pd.read_csv('ML_data/ML_dev_clean.csv', index_col=0)
env_clean =pd.read_csv('ML_data/ML_env_clean.csv', index_col=0)
edu_clean =pd.read_csv('ML_data/ML_edu_clean.csv', index_col=0)
pov_clean =pd.read_csv('ML_data/ML_pov_clean.csv', index_col=0)

# %%
fin_clean.shape
# Out:
# (346, 65)

# %%
econ_clean.shape
# Out:
# (346, 260)

# %%
econ_fin_dev_combo = pd.concat([econ_clean, fin_clean, dev_clean], axis=1)

# %%
econ_fin_dev_combo.shape
# Out:
# (346, 460)

# %%
econ_fin_dev_combo.dropna(axis=0, how='all', inplace=True)
econ_fin_dev_combo.dropna(axis=1, how='all', inplace=True)
econfindev_stack = get_stack(econ_fin_dev_combo)
# Out:
# Afghanistan
# Albania
# Algeria
# American Samoa
# Andorra
# Angola
# Antigua and Barbuda
# Arab World
# Argentina
# Armenia
# Aruba
# Australia
# Austria
# Azerbaijan
# Bahamas, The
# Bahrain
# Bangladesh
# Barbados
# Belarus
# Belgium
# Belize
# Benin
# Bermuda
# Bhutan
# Bolivia
# Bosnia and Herzegovina
# Botswana
# Brazil
# British Virgin Islands
# Brunei Darussalam
# Bulgaria
# Burkina Faso
# Burundi
# Cabo Verde
# Cambodia
# Cameroon
# Canada
# Cape Verde
# Caribbean small states
# Cayman Islands
# Central African Republic
# Central Europe and the Baltics
# Chad
# Channel Islands
# Chile
# China
# Colombia
# Comoros
# Congo, Dem. Rep.
# Congo, Rep.
# Costa Rica
# Cote d'Ivoire
# Croatia
# Cuba
# Curacao
# Cyprus
# Czech Republic
# Denmark
# Djibouti
# Dominica
# Dominican Republic
# Early-demographic dividend
# East Asia & Pacific
# East Asia & Pacific (IBRD only)
# East Asia & Pacific (IDA & IBRD countries)
# East Asia & Pacific (IDA & IBRD)
# East Asia & Pacific (IDA total)
# East Asia & Pacific (developing only)
# East Asia & Pacific (excluding high income)
# Ecuador
# Egypt, Arab Rep.
# El Salvador
# Equatorial Guinea
# Eritrea
# Estonia
# Ethiopia
# Euro area
# Europe & Central Asia
# Europe & Central Asia (IBRD only)
# Europe & Central Asia (IDA & IBRD countries)
# Europe & Central Asia (IDA & IBRD)
# Europe & Central Asia (IDA total)
# Europe & Central Asia (developing only)
# Europe & Central Asia (excluding high income)
# European Union
# Faeroe Islands
# Faroe Islands
# Fiji
# Finland
# Fragile and conflict affected situations
# France
# French Polynesia
# Gabon
# Gambia, The
# Georgia
# Germany
# Ghana
# Gibraltar
# Greece
# Greenland
# Grenada
# Guam
# Guatemala
# Guinea
# Guinea-Bissau
# Guyana
# Haiti
# Heavily indebted poor countries (HIPC)
# High income
# Honduras
# Hong Kong SAR, China
# Hungary
# IBRD only
# IDA & IBRD total
# IDA blend
# IDA countries classified as fragile situations
# IDA countries not classified as fragile situations
# IDA only
# IDA total
# Iceland
# India
# Indonesia
# Iran, Islamic Rep.
# Iraq
# Ireland
# Isle of Man
# Israel
# Italy
# Jamaica
# Japan
# Jordan
# Kazakhstan
# Kenya
# Kiribati
# Korea, Dem. People's Rep.
# Korea, Dem. People’s Rep.
# Korea, Dem. Rep.
# Korea, Rep.
# Kosovo
# Kuwait
# Kyrgyz Republic
# Lao PDR
# Late-demographic dividend
# Latin America & Caribbean
# Latin America & Caribbean (IBRD only)
# Latin America & Caribbean (IDA & IBRD)
# Latin America & Caribbean (IDA total)
# Latin America & Caribbean (developing only)
# Latin America & Caribbean (excluding high income)
# Latin America & the Caribbean (IDA & IBRD countries)
# Latvia
# Least developed countries: UN classification
# Lebanon
# Lesotho
# Liberia
# Libya
# Liechtenstein
# Lithuania
# Low & middle income
# Low income
# Lower middle income
# Luxembourg
# Macao SAR, China
# Macedonia, FYR
# Madagascar
# Malawi
# Malaysia
# Maldives
# Mali
# Malta
# Marshall Islands
# Mauritania
# Mauritius
# Mexico
# Micronesia, Fed. Sts.
# Middle East & North Africa
# Middle East & North Africa (IBRD only)
# Middle East & North Africa (IDA & IBRD countries)
# Middle East & North Africa (IDA & IBRD)
# Middle East & North Africa (IDA total)
# Middle East & North Africa (developing only)
# Middle East & North Africa (excluding high income)
# Middle income
# Moldova
# Monaco
# Mongolia
# Montenegro
# Morocco
# Mozambique
# Myanmar
# Namibia
# Nauru
# Nepal
# Netherlands
# New Caledonia
# New Zealand
# Nicaragua
# Niger
# Nigeria
# North America
# Northern Mariana Islands
# Norway
# Not classified
# OECD members
# Oman
# Other small states
# Pacific island small states
# Pakistan
# Palau
# Panama
# Papua New Guinea
# Paraguay
# Peru
# Philippines
# Poland
# Portugal
# Post-demographic dividend
# Pre-demographic dividend
# Puerto Rico
# Qatar
# Romania
# Russian Federation
# Rwanda
# Samoa
# San Marino
# Sao Tome and Principe
# Saudi Arabia
# Senegal
# Serbia
# Seychelles
# Sierra Leone
# Singapore
# Sint Maarten (Dutch part)
# Slovak Republic
# Slovenia
# Small states
# Solomon Islands
# Somalia
# South Africa
# South Asia
# South Asia (IBRD only)
# South Asia (IDA & IBRD)
# South Asia (IDA total)
# South Sudan
# Spain
# Sri Lanka
# St. Kitts and Nevis
# St. Lucia
# St. Martin (French part)
# St. Vincent and the Grenadines
# Sub-Saharan Africa
# Sub-Saharan Africa (IBRD only)
# Sub-Saharan Africa (IDA & IBRD countries)
# Sub-Saharan Africa (IDA & IBRD)
# Sub-Saharan Africa (IDA total)
# Sub-Saharan Africa (developing only)
# Sub-Saharan Africa (excluding high income)
# Sudan
# Suriname
# Swaziland
# Sweden
# Switzerland
# Syrian Arab Republic
# Taiwan, China
# Tajikistan
# Tanzania
# Thailand
# Timor-Leste
# Togo
# Tonga
# Trinidad and Tobago
# Tunisia
# Turkey
# Turkmenistan
# Turks and Caicos Islands
# Tuvalu
# Uganda
# Ukraine
# United Arab Emirates
# United Kingdom
# United States
# Upper middle income
# Uruguay
# Uzbekistan
# Vanuatu
# Venezuela, RB
# Vietnam
# Virgin Islands (U.S.)
# West Bank and Gaza
# World
# Yemen, Rep.
# Zambia
# Zimbabwe

# %%
econfindev_stack.shape
# Out:
# (16994, 439)

# %%
econfindev_stack.dropna(axis=0, how='all', inplace=True)
econfindev_stack.dropna(axis=1, how='all', inplace=True)
econfindev_stack.shape
# Out:
# (15250, 439)

# %%
econfindev_stack.to_csv('ML_econfindev_stack.csv')

# %%
health_econ_dev_combo = pd.concat([econ_clean, health, dev_clean], axis=1)

# %%
health_clean.dropna(axis=0, how='all', inplace=True)
health_clean.dropna(axis=1, how='all', inplace=True)
health_stack = get_stack(health_clean)
# Out:
# /opt/conda/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /opt/conda/lib/python2.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Burundi, Rutana
# Panama, Herrera
# Afghanistan, Nangarhar
# Lao PDR, Phongsali
# Romania, Bihor
# Bulgaria, Sofia
# India, Andhra Pradesh
# Croatia, Primorje-gorski Kota
# Nigeria, Akwa Ibom
# Dominican Republic, San Jose de Ocoa
# Iraq, Baghdad
# East Asia & Pacific (IDA & IBRD countries)
# Hungary, Hajdu-bihar
# Russian Federation, Komi Rep.
# Poland, Podkarpackie
# Albania, Kukes
# Guinea-Bissau, Bafata
# Trinidad and Tobago, Sangre Grande
# Croatia, Dubrovnik-neretva
# Turkey, Hatay
# Algeria, Saida
# Algeria, Bordj Bou Arrer
# Honduras, Francisco Morazan
# Moldova, Rezina
# Vietnam, Binh Thuan
# Middle East & North Africa (IBRD only)
# Madagascar, Haute Matsiatra
# Honduras, Copan
# Algeria, Tlemcen
# Azerbaijan, Absheron
# Iraq, Dahuk
# Tunisia, Le Kef
# Burundi, Cibitoke
# Korea, Rep., Chungchongnam-do
# Cuba, Guantanamo
# Venezuela, RB, Barinas
# Lesotho, Berea
# Russian Federation, Tverskaya Oblast
# China, Anhui Sheng
# Turkey, Giresun
# Algeria, Tindouf
# Romania, Galati
# India, Tripura
# Peru, Cajamarca
# Turkey, Osmaniye
# Dominican Republic, La Vega
# Indonesia, Bali, Prop.
# Yemen, Rep., Raymah
# Vietnam, Quang Binh
# Iran, Islamic Rep., Zanjan
# Afghanistan, Kabul
# Bolivia, Santa Cruz
# Albania, Tirane
# Thailand, Roi Et
# Thailand, Phetchaburi
# Tanzania, Singida
# Croatia, Istra
# Sudan, Gadaref
# Tanzania, Ruvuma
# Czech Republic, Liberec
# Uruguay, Soriano
# Cameroon, Adamaoua
# Afghanistan, Paktya
# Montenegro, Pljevlja
# Dominican Republic, Hermanas Mirabal
# Russian Federation, Udmurtiya Rep.
# Tuvalu
# Estonia, Laane
# Guatemala, Baja Verapaz
# Senegal, Ziguinchor
# Peru, Moquegua
# Bulgaria, Razgrad
# Georgia, Tbilisi
# Madagascar, Alaotra Mangoro
# India, Madhya Pradesh
# Iraq, Salah al-Din
# Angola, Cuando Cubango
# Angola, Cuanza Sul
# Guatemala, Guatemala
# Turkey, Ardahan
# Angola, Benguela
# Nigeria, Jigawa
# Tanzania, Katavi
# Mexico, Chiapas
# India, Nagaland
# Benin, Atlantique
# Colombia
# Bhutan, Gasa
# Iran, Islamic Rep., Sistan-o baluchestan
# Colombia, Caqueta
# Colombia, Bolivar
# Algeria, El-Tarf
# Timor-Leste, Baucau
# Russian Federation, Tatarstan Rep.
# Cameroon, Nord
# Trinidad and Tobago, Penal-Debe
# Korea, Rep., Kang-won-do
# Ecuador, Pichincha
# Burkina Faso, Centre-est
# Bulgaria, Plovdiv
# India, Daman and Diu
# Sri Lanka, Central
# Trinidad and Tobago, Point Fortin
# Uruguay, Maldonado
# Algeria, Oum El Bouaghi
# Uruguay, Colonia
# Afghanistan, Kunduz
# Colombia, Cesar
# Lesotho, Maseru
# Venezuela, RB, Nueva Esparta
# Cambodia, Kandal
# Faeroe Islands
# Angola, Cunene
# Indonesia, Riau, Prop.
# Vietnam, Soc Trang
# Rwanda, Eastern
# Montenegro, Danilovgrad
# Thailand, Suphanburi
# Kiribati
# Vietnam, Phu Tho
# Iraq
# Fragile and conflict affected situations
# Algeria, Mascara
# Mongolia, Bayanxongor
# Russian Federation, Adygeya Rep.
# Bulgaria, Targovishte
# Algeria, Tebessa
# Mexico, Tlaxcala
# Vietnam, Bac Ninh
# China, Chongqing Shi
# Russian Federation, Permskaya Oblast
# Djibouti
# Antigua and Barbuda
# Albania, Durres
# Sub-Saharan Africa (IDA total)
# Sub-Saharan Africa (excluding high income)
# Liberia, Bong
# Moldova, Criuleni
# Venezuela, RB, Distrito Capital
# Myanmar, Mon
# Tunisia, Tataouine
# India, Arunachal Pradesh
# Cambodia, Stung Treng
# Sub-Saharan Africa (IDA & IBRD)
# Korea, Rep., Seoul
# Sudan, Northern Darfur
# Tunisia, Medenine
# Sri Lanka, Sabaragamuwa
# Zambia, Muchinga
# Trinidad and Tobago, Tobago
# Bulgaria, Burgas
# Mexico, Yucatan
# Estonia, Pärnu
# India, Rajasthan
# Bhutan, Paro
# Russian Federation, Kamchatskaya Oblast
# Jordan, Jarash
# Vietnam, Quang Tri
# Kazakhstan, Kustanayskaya
# Tanzania, Mtwara
# Ghana, Greater Accra
# Nigeria, Ebonyi
# Algeria, Mila
# Montenegro, Rozaj
# Tunisia, Gafsa
# Thailand, Phangnga
# Venezuela, RB, Dependencias Federales
# Congo, Dem. Rep.
# Kenya, Nyanza
# Ecuador, El Oro
# Guatemala, San Marcos
# Lao PDR, Oudomxai
# Peru, Lima
# Ecuador, Sucumbios
# Turkmenistan
# Hungary, Borsod-abauj-zemplen
# Kazakhstan, Jambylslkaya
# Egypt, Arab Rep., Menoufia
# Estonia, Tartu
# Myanmar, Sagaing
# Brazil, Espirito Santo
# India, Assam
# Brazil, Rondonia
# Russian Federation, Chuvashiya Rep.
# Sudan, Nile River
# Bhutan, Samtse
# Syrian Arab Republic, Idleb
# Tunisia, Sousse
# Mali, Gao
# Channel Islands
# Tanzania, Lindi
# Kazakhstan, Almatinskaya
# Angola, Uige
# Burkina Faso, Est
# Tanzania, Kaskazini Unguja
# Timor-Leste, Oecussi
# Guinea, Conakry
# Moldova, Cimislia
# Seychelles
# Vietnam, Hoa Binh
# Afghanistan, Baghlan
# Peru, Tacna
# Guatemala, Chimaltenango
# Egypt, Arab Rep., Kafr El-Shikh
# Latin America & Caribbean
# Algeria, Boumerdes
# Iraq, Ninewa
# Afghanistan
# Russian Federation, Novgorodskaya Oblast
# Colombia, Narino
# Montenegro, Budva
# Bulgaria, Veliko Tarnovo
# Russian Federation, Nizhegorodskaya Oblast
# Benin, Mono
# Slovenia, Gorenjska
# Vanuatu
# Venezuela, RB, Vargas
# Argentina, Tucuman
# Philippines, Bicoll Region
# Nicaragua, Boaco
# Uruguay, Lavalleja
# Venezuela, RB, Delta Amacuro
# Venezuela, RB, Lara
# Liberia, Montserrado
# Nigeria, Edo
# Russian Federation, Lipetskaya Oblast
# Mexico, Zacatecas
# Cambodia, Battambang
# Sri Lanka
# (128586, 217)

# %%
health_stack.shape
# Out:
# (128586, 217)

# %%
health_stack.dropna(axis=0, how='all', inplace=True)
health_stack.dropna(axis=1, how='all', inplace=True)
health_stack.shape
# Out:
# (15207, 217)

# %%
health_stack.to_csv('ML_health_stack.csv')

# %%
edu_clean.dropna(axis=0, how='all', inplace=True)
edu_clean.dropna(axis=1, how='all', inplace=True)
edu_stack = get_stack(edu_clean)
# Out:
# /opt/conda/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /opt/conda/lib/python2.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Canada
# Sao Tome and Principe
# Turkmenistan
# Lao PDR
# Arab World
# Lithuania
# Cambodia
# Switzerland
# Ethiopia
# OECD members
# Swaziland
# South Asia
# Argentina
# Bolivia
# Bahamas, The
# Burkina Faso
# Bahrain
# Saudi Arabia
# Lebanon
# South Asia (IDA & IBRD)
# Japan
# Channel Islands
# American Samoa
# Northern Mariana Islands
# Slovenia
# Guatemala
# IDA total
# Bosnia and Herzegovina
# Guinea
# Russian Federation
# World
# St. Lucia
# Congo, Rep.
# Dominica
# Liberia
# South Asia (IDA total)
# Maldives
# St. Martin (French part)
# Pakistan
# Oman
# Tanzania
# Early-demographic dividend
# Cabo Verde
# Mauritania
# Greenland
# Gabon
# Monaco
# New Zealand
# Spain
# European Union
# Jamaica
# Albania
# Samoa
# Korea, Dem. People’s Rep.
# Slovak Republic
# Kazakhstan
# Guam
# Uruguay
# India
# Azerbaijan
# Lesotho
# Middle East & North Africa
# Europe & Central Asia (IDA & IBRD countries)
# United Arab Emirates
# Latin America & Caribbean
# Aruba
# Upper middle income
# Tajikistan
# Pacific island small states
# Turkey
# Afghanistan
# Venezuela, RB
# Bangladesh
# East Asia & Pacific
# Solomon Islands
# Korea, Rep.
# Palau
# San Marino
# French Polynesia
# France
# Syrian Arab Republic
# Bermuda
# Namibia
# Somalia
# Peru
# Vanuatu
# Nauru
# Seychelles
# Late-demographic dividend
# Cote d'Ivoire
# Middle East & North Africa (IDA & IBRD)
# Benin
# Other small states
# Cuba
# Cameroon
# Montenegro
# Low & middle income
# Togo
# East Asia & Pacific (IBRD only)
# China
# Armenia
# Jordan
# Timor-Leste
# Dominican Republic
# Ukraine
# Ghana
# Tonga
# Finland
# Colombia
# Libya
# Sweden
# Cayman Islands
# Central African Republic
# New Caledonia
# North America
# Sub-Saharan Africa (IDA total)
# Liechtenstein
# Belarus
# British Virgin Islands
# Kenya
# Micronesia, Fed. Sts.
# Europe & Central Asia (IDA & IBRD)
# Korea, Dem. Rep.
# Poland
# Europe & Central Asia (IDA total)
# Bulgaria
# Mauritius
# Romania
# Angola
# Central Europe and the Baltics
# Chad
# South Africa
# St. Vincent and the Grenadines
# Cyprus
# Caribbean small states
# Brunei Darussalam
# Qatar
# Pre-demographic dividend
# Middle income
# Austria
# Vietnam
# Mozambique
# Uganda
# Kyrgyz Republic
# Hungary
# Niger
# Isle of Man
# United States
# Brazil
# Sub-Saharan Africa (IDA & IBRD countries)
# Virgin Islands (U.S.)
# Faroe Islands
# Europe & Central Asia (excluding high income)
# Panama
# Mali
# Latin America & Caribbean (IBRD only)
# Costa Rica
# Luxembourg
# Andorra
# Norway
# Euro area
# Gibraltar
# Ireland
# Italy
# Nigeria
# Middle East & North Africa (IBRD only)
# Lower middle income
# Ecuador
# IDA & IBRD total
# Australia
# Algeria
# El Salvador
# Tuvalu
# IDA only
# Latin America & the Caribbean (IDA & IBRD countries)
# St. Kitts and Nevis
# Czech Republic
# IDA countries classified as fragile situations
# Sub-Saharan Africa
# Middle East & North Africa (excluding high income)
# Chile
# Marshall Islands
# Belgium
# Kiribati
# Haiti
# Belize
# Fragile and conflict affected situations
# Sierra Leone
# Middle East & North Africa (IDA total)
# Georgia
# South Asia (IBRD only)
# Denmark
# Post-demographic dividend
# Puerto Rico
# Moldova
# Portugal
# Morocco
# Croatia
# Mongolia
# Guinea-Bissau
# Thailand
# Macedonia, FYR
# Grenada
# Korea, Dem. People's Rep.
# Yemen, Rep.
# Latin America & Caribbean (excluding high income)
# Iraq
# Egypt, Arab Rep.
# Estonia
# Kosovo
# East Asia & Pacific (IDA & IBRD)
# Equatorial Guinea
# Hong Kong SAR, China
# Uzbekistan
# West Bank and Gaza
# Djibouti
# Rwanda
# Antigua and Barbuda
# Low income
# High income
# Burundi
# East Asia & Pacific (IDA total)
# Least developed countries: UN classification
# IDA blend
# Barbados
# Madagascar
# Latin America & Caribbean (IDA total)
# Sub-Saharan Africa (excluding high income)
# Curacao
# Bhutan
# Sudan
# Nepal
# Singapore
# Malta
# Netherlands
# Macao SAR, China
# Suriname
# Kuwait
# Turks and Caicos Islands
# Europe & Central Asia
# Iran, Islamic Rep.
# Israel
# Indonesia
# Malaysia
# Iceland
# Zambia
# Senegal
# Papua New Guinea
# Malawi
# IDA countries not classified as fragile situations
# Trinidad and Tobago
# Zimbabwe
# Germany
# Sub-Saharan Africa (IDA & IBRD)
# Europe & Central Asia (IBRD only)
# East Asia & Pacific (excluding high income)
# Philippines
# Eritrea
# Small states
# Sub-Saharan Africa (IBRD only)
# Mexico
# Sri Lanka
# Not classified
# Latvia
# South Sudan
# Guyana
# IBRD only
# East Asia & Pacific (IDA & IBRD countries)
# Honduras
# Myanmar
# Latin America & Caribbean (IDA & IBRD)
# Tunisia
# Nicaragua
# Faeroe Islands
# Congo, Dem. Rep.
# Serbia
# Comoros
# United Kingdom
# Middle East & North Africa (IDA & IBRD countries)
# Gambia, The
# Sint Maarten (Dutch part)
# Greece
# Paraguay
# Fiji
# Botswana
# Heavily indebted poor countries (HIPC)

# %%
edu_stack.shape
# Out:
# (16588, 158)

# %%
edu_stack.dropna(axis=0, how='all', inplace=True)
edu_stack.dropna(axis=1, how='all', inplace=True)
edu_stack.shape
# Out:
# (14638, 112)

# %%
edu_stack.to_csv('ML_edu_stack.csv')

# %%
dev_clean.dropna(axis=0, how='all', inplace=True)
dev_clean.dropna(axis=1, how='all', inplace=True)
dev_stack = get_stack(dev_clean)
# Out:
# /opt/conda/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /opt/conda/lib/python2.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# Middle East & North Africa (excluding high income)
# Chile
# Marshall Islands
# Belgium
# Kiribati
# Haiti
# Belize
# Fragile and conflict affected situations
# Sierra Leone
# Middle East & North Africa (IDA total)
# Georgia
# South Asia (IBRD only)
# Denmark
# Post-demographic dividend
# Puerto Rico
# Moldova
# Portugal
# Morocco
# Croatia
# Mongolia
# Guinea-Bissau
# Thailand
# Macedonia, FYR
# Grenada
# Korea, Dem. People's Rep.
# Yemen, Rep.
# Latin America & Caribbean (excluding high income)
# Iraq
# Egypt, Arab Rep.
# Estonia
# Kosovo
# East Asia & Pacific (IDA & IBRD)
# Equatorial Guinea
# Hong Kong SAR, China
# Uzbekistan
# West Bank and Gaza
# Djibouti
# Rwanda
# Antigua and Barbuda
# Low income
# High income
# Burundi
# East Asia & Pacific (IDA total)
# Least developed countries: UN classification
# IDA blend
# Barbados
# Madagascar
# Latin America & Caribbean (IDA total)
# Sub-Saharan Africa (excluding high income)
# Curacao
# Bhutan
# Sudan
# Nepal
# Singapore
# Malta
# Netherlands
# Macao SAR, China
# Suriname
# Kuwait
# Turks and Caicos Islands
# Europe & Central Asia
# Iran, Islamic Rep.
# Israel
# Indonesia
# Malaysia
# Iceland
# Zambia
# Senegal
# Papua New Guinea
# Malawi
# IDA countries not classified as fragile situations
# Trinidad and Tobago
# Zimbabwe
# Germany
# Sub-Saharan Africa (IDA & IBRD)
# Europe & Central Asia (IBRD only)
# East Asia & Pacific (excluding high income)
# Philippines
# Eritrea
# Small states
# Sub-Saharan Africa (IBRD only)
# Mexico
# Sri Lanka
# Not classified
# Latvia
# South Sudan
# Guyana
# IBRD only
# East Asia & Pacific (IDA & IBRD countries)
# Honduras
# Myanmar
# Latin America & Caribbean (IDA & IBRD)
# Tunisia
# Nicaragua
# Faeroe Islands
# Congo, Dem. Rep.
# Serbia
# Comoros
# United Kingdom
# Middle East & North Africa (IDA & IBRD countries)
# Gambia, The
# Sint Maarten (Dutch part)
# Greece
# Paraguay
# Fiji
# Botswana
# Heavily indebted poor countries (HIPC)

# %%
dev_stack.shape
# Out:
# (16588, 132)

# %%
dev_stack.dropna(axis=0, how='all', inplace=True)
dev_stack.dropna(axis=1, how='all', inplace=True)
dev_stack.shape
# Out:
# (15250, 132)

# %%
dev_stack.to_csv('ML_dev_stack.csv')

# %%
fin_clean.dropna(axis=0, how='all', inplace=True)
fin_clean.dropna(axis=1, how='all', inplace=True)
fin_stack = get_stack(fin_clean)
# Out:
# /opt/conda/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /opt/conda/lib/python2.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Canada
# OECD members
# Swaziland
# Cameroon
# Burkina Faso
# East Asia & Pacific (IDA & IBRD countries)
# Sub-Saharan Africa
# Russian Federation
# Dominica
# Early-demographic dividend
# Middle East & North Africa (IBRD only)
# Madagascar
# Yemen, Rep.
# Upper middle income
# Tajikistan
# Turkey
# Nauru
# Norway
# Montenegro
# Indonesia
# Libya
# Finland
# Central African Republic
# Liechtenstein
# Micronesia, Fed. Sts.
# United States
# Portugal
# Fiji
# Kyrgyz Republic
# Kuwait
# Latin America & Caribbean (IBRD only)
# Costa Rica
# Nigeria
# Ecuador
# Australia
# Tuvalu
# IDA only
# South Asia (IBRD only)
# East Asia & Pacific (developing only)
# Denmark
# Post-demographic dividend
# Morocco
# Estonia
# Kosovo
# Lebanon
# Colombia
# Latin America & Caribbean (IDA total)
# Palau
# Nepal
# Netherlands
# Suriname
# Middle East & North Africa (developing only)
# Jordan
# Eritrea
# Not classified
# IBRD only
# Equatorial Guinea
# Serbia
# Greece
# Heavily indebted poor countries (HIPC)
# Sao Tome and Principe
# Arab World
# Bolivia
# Ghana
# Saudi Arabia
# South Asia (IDA & IBRD)
# American Samoa
# Guatemala
# World
# Spain
# Oman
# Cabo Verde
# Gabon
# Greenland
# United Arab Emirates
# India
# Lesotho
# East Asia & Pacific (IBRD only)
# Europe & Central Asia (IDA & IBRD countries)
# Kenya
# Venezuela, RB
# Northern Mariana Islands
# East Asia & Pacific
# Solomon Islands
# French Polynesia
# Bermuda
# Peru
# Late-demographic dividend
# Cote d'Ivoire
# Middle East & North Africa (IDA & IBRD)
# Benin
# Other small states
# China
# Ukraine
# Tonga
# Cayman Islands
# Mauritius
# Mali
# Europe & Central Asia (IDA total)
# Bulgaria
# Angola
# Chad
# South Africa
# Caribbean small states
# Brunei Darussalam
# Senegal
# Uganda
# Hungary
# Niger
# Brazil
# Virgin Islands (U.S.)
# Middle East & North Africa
# Faeroe Islands
# Lower middle income
# IDA & IBRD total
# Algeria
# St. Kitts and Nevis
# Marshall Islands
# Belgium
# Kiribati
# Haiti
# Iraq
# Fragile and conflict affected situations
# Middle East & North Africa (IDA total)
# Guinea-Bissau
# Korea, Dem. People's Rep.
# Latin America & Caribbean (excluding high income)
# Isle of Man
# Mexico
# Korea, Rep.
# Djibouti
# Timor-Leste
# High income
# Sub-Saharan Africa (IDA total)
# Least developed countries: UN classification
# IDA blend
# Sub-Saharan Africa (excluding high income)
# Sub-Saharan Africa (developing only)
# Sub-Saharan Africa (IDA & IBRD)
# Iceland
# Zambia
# Germany
# Europe & Central Asia (IBRD only)
# Kazakhstan
# Small states
# Guyana
# Honduras
# Latin America & Caribbean (IDA & IBRD)
# Congo, Dem. Rep.
# Latin America & the Caribbean (IDA & IBRD countries)
# Sub-Saharan Africa (IBRD only)
# Croatia
# Comoros
# Turkmenistan
# Ethiopia
# Middle East & North Africa (IDA & IBRD countries)
# Channel Islands
# IDA total
# Bosnia and Herzegovina
# St. Lucia
# Liberia
# Maldives
# Tanzania
# Monaco
# Latin America & Caribbean
# East Asia & Pacific (IDA & IBRD)
# Afghanistan
# France
# Vanuatu
# Malawi
# Taiwan, China
# Antigua and Barbuda
# Dominican Republic
# Latin America & Caribbean (developing only)
# Korea, Dem. Rep.
# St. Vincent and the Grenadines
# Nicaragua
# Middle income
# Guinea
# Panama
# Luxembourg
# Cape Verde
# Gibraltar
# Ireland
# Curacao
# El Salvador
# Thailand
# Belize
# Sierra Leone
# Georgia
# Poland
# Moldova
# Macedonia, FYR
# Uzbekistan
# IDA countries classified as fragile situations
# Cyprus
# Barbados
# Qatar
# Italy
# Sudan
# Euro area
# Israel
# Malaysia
# Papua New Guinea
# Zimbabwe
# Europe & Central Asia
# East Asia & Pacific (excluding high income)
# Mauritania
# Trinidad and Tobago
# Latvia
# United Kingdom
# Paraguay
# Botswana
# Lao PDR
# Lithuania
# Cambodia
# Slovak Republic
# Aruba
# South Asia
# Argentina
# Bahamas, The
# Bahrain
# Slovenia
# IDA countries not classified as fragile situations
# Congo, Rep.
# South Asia (IDA total)
# Jamaica
# West Bank and Gaza
# New Zealand
# European Union
# Pakistan
# Albania
# Samoa
# Korea, Dem. People’s Rep.
# Guam
# Azerbaijan
# Pacific island small states
# Bangladesh
# Syrian Arab Republic
# Rwanda
# East Asia & Pacific (IDA total)
# Somalia
# Cuba
# Low & middle income
# Togo
# Armenia
# North America
# Sweden
# Vietnam
# British Virgin Islands
# Europe & Central Asia (IDA & IBRD)
# Romania
# Central Europe and the Baltics
# Egypt, Arab Rep.
# Pre-demographic dividend
# Austria
# Mozambique
# Japan
# Sub-Saharan Africa (IDA & IBRD countries)
# Faroe Islands
# Europe & Central Asia (excluding high income)
# Czech Republic
# Belarus
# Middle East & North Africa (excluding high income)
# Chile
# Puerto Rico
# San Marino
# Namibia
# Mongolia
# Switzerland
# Grenada
# Seychelles
# Uruguay
# Hong Kong SAR, China
# Low income
# Burundi
# Turks and Caicos Islands
# Bhutan
# Malta
# Macao SAR, China
# St. Martin (French part)
# Iran, Islamic Rep.
# Europe & Central Asia (developing only)
# Philippines
# New Caledonia
# Andorra
# South Sudan
# Myanmar
# Tunisia
# Singapore
# Gambia, The
# Sint Maarten (Dutch part)
# Sri Lanka

# %%
fin_stack.shape
# Out:
# (16994, 65)

# %%
fin_stack.dropna(axis=0, how='all', inplace=True)
fin_stack.dropna(axis=1, how='all', inplace=True)
fin_stack.shape
# Out:
# (14396, 65)

# %%
fin_stack.to_csv('ML_fin_stack.csv')

# %%
env_clean.dropna(axis=0, how='all', inplace=True)
env_clean.dropna(axis=1, how='all', inplace=True)
env_stack = get_stack(env_clean)
# Out:
# /opt/conda/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /opt/conda/lib/python2.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Canada
# Sao Tome and Principe
# Turkmenistan
# Lao PDR
# Arab World
# Lithuania
# Cambodia
# Switzerland
# Ethiopia
# OECD members
# Swaziland
# South Asia
# Argentina
# Bolivia
# Bahamas, The
# Burkina Faso
# Bahrain
# Saudi Arabia
# Lebanon
# South Asia (IDA & IBRD)
# Japan
# Channel Islands
# American Samoa
# Northern Mariana Islands
# Slovenia
# Guatemala
# IDA total
# Bosnia and Herzegovina
# Guinea
# Russian Federation
# World
# St. Lucia
# Congo, Rep.
# Dominica
# Liberia
# South Asia (IDA total)
# Maldives
# St. Martin (French part)
# Pakistan
# Oman
# Tanzania
# Early-demographic dividend
# Cabo Verde
# Mauritania
# Greenland
# Gabon
# Monaco
# New Zealand
# Spain
# European Union
# Jamaica
# Albania
# Samoa
# Korea, Dem. People’s Rep.
# Slovak Republic
# Kazakhstan
# Guam
# Uruguay
# India
# Azerbaijan
# Lesotho
# Middle East & North Africa
# Europe & Central Asia (IDA & IBRD countries)
# United Arab Emirates
# Latin America & Caribbean
# Aruba
# Upper middle income
# Tajikistan
# Pacific island small states
# Turkey
# Afghanistan
# Zambia
# Senegal
# Papua New Guinea
# Malawi
# IDA countries not classified as fragile situations
# Trinidad and Tobago
# Zimbabwe
# Germany
# Sub-Saharan Africa (IDA & IBRD)
# Europe & Central Asia (IBRD only)
# East Asia & Pacific (excluding high income)
# Philippines
# Eritrea
# Small states
# Sub-Saharan Africa (IBRD only)
# Mexico
# Sri Lanka
# Not classified
# Latvia
# South Sudan
# Guyana
# IBRD only
# East Asia & Pacific (IDA & IBRD countries)
# Honduras
# Myanmar
# Latin America & Caribbean (IDA & IBRD)
# Tunisia
# Nicaragua
# Faeroe Islands
# Congo, Dem. Rep.
# Serbia
# Comoros
# United Kingdom
# Middle East & North Africa (IDA & IBRD countries)
# Gambia, The
# Sint Maarten (Dutch part)
# Greece
# Paraguay
# Fiji
# Botswana
# Heavily indebted poor countries (HIPC)

# %%
env_stack.shape
# Out:
# (16588, 49)

# %%
env_stack.dropna(axis=0, how='all', inplace=True)
env_stack.dropna(axis=1, how='all', inplace=True)
env_stack.shape
# Out:
# (14669, 49)

# %%
env_stack.to_csv('ML_env_stack.csv')

# %%
pov_clean.dropna(axis=0, how='all', inplace=True)
pov_clean.dropna(axis=1, how='all', inplace=True)
pov_stack = get_stack(pov_clean)
# Out:
# /opt/conda/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /opt/conda/lib/python2.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Canada
# Sao Tome and Principe
# Turkmenistan
# Lao PDR
# Arab World
# Lithuania
# Cambodia
# Switzerland
# Ethiopia
# OECD members
# Swaziland
# South Asia
# Argentina
# Bolivia
# Bahamas, The
# Burkina Faso
# Bahrain
# Saudi Arabia
# Lebanon
# South Asia (IDA & IBRD)
# Japan
# Channel Islands
# American Samoa
# Northern Mariana Islands
# Slovenia
# Guatemala
# IDA total
# Bosnia and Herzegovina
# Guinea
# Russian Federation
# World
# St. Lucia
# Congo, Rep.
# Dominica
# Liberia
# South Asia (IDA total)
# Maldives
# St. Martin (French part)
# Pakistan
# Oman
# Tanzania
# Early-demographic dividend
# Cabo Verde
# Mauritania
# Greenland
# Gabon
# Monaco
# New Zealand
# Spain
# European Union
# Jamaica
# Albania
# Samoa
# Korea, Dem. People’s Rep.
# Slovak Republic
# Kazakhstan
# Guam
# Uruguay
# India
# Azerbaijan
# Lesotho
# Middle East & North Africa
# Europe & Central Asia (IDA & IBRD countries)
# United Arab Emirates
# Latin America & Caribbean
# Aruba
# Upper middle income
# Tajikistan
# Pacific island small states
# Turkey
# Afghanistan
# Venezuela, RB
# Bangladesh
# East Asia & Pacific
# Solomon Islands
# Korea, Rep.
# Palau
# San Marino
# French Polynesia
# France
# Syrian Arab Republic
# Bermuda
# Namibia
# Somalia
# Peru
# Vanuatu
# Nauru
# Seychelles
# Late-demographic dividend
# Cote d'Ivoire
# Middle East & North Africa (IDA & IBRD)
# Benin
# Other small states
# Cuba
# Cameroon
# Montenegro
# Low & middle income
# Togo
# East Asia & Pacific (IBRD only)
# China
# Armenia
# Jordan
# Timor-Leste
# Dominican Republic
# Ukraine
# Ghana
# Tonga
# Finland
# Colombia
# Libya
# Sweden
# Cayman Islands
# Central African Republic
# New Caledonia
# North America
# Sub-Saharan Africa (IDA total)
# Liechtenstein
# Belarus
# British Virgin Islands
# Kenya
# Micronesia, Fed. Sts.
# Europe & Central Asia (IDA & IBRD)
# Korea, Dem. Rep.
# Poland
# Europe & Central Asia (IDA total)
# Bulgaria
# Mauritius
# Romania
# Angola
# Central Europe and the Baltics
# Chad
# South Africa
# St. Vincent and the Grenadines
# Cyprus
# Caribbean small states
# Brunei Darussalam
# Qatar
# Pre-demographic dividend
# Middle income
# Austria
# Vietnam
# Mozambique
# Uganda
# Kyrgyz Republic
# Hungary
# Niger
# Isle of Man
# United States
# Brazil
# Sub-Saharan Africa (IDA & IBRD countries)
# Virgin Islands (U.S.)
# Faroe Islands
# Europe & Central Asia (excluding high income)
# Panama
# Mali
# Latin America & Caribbean (IBRD only)
# Costa Rica
# Luxembourg
# Andorra
# Norway
# Euro area
# Gibraltar
# Ireland
# Italy
# Nigeria
# Middle East & North Africa (IBRD only)
# Lower middle income
# Ecuador
# IDA & IBRD total
# Australia
# Algeria
# El Salvador
# Tuvalu
# IDA only
# Latin America & the Caribbean (IDA & IBRD countries)
# St. Kitts and Nevis
# Czech Republic
# IDA countries classified as fragile situations
# Sub-Saharan Africa
# Middle East & North Africa (excluding high income)
# Chile
# Marshall Islands
# Belgium
# Kiribati
# Haiti
# Belize
# Fragile and conflict affected situations
# Sierra Leone
# Middle East & North Africa (IDA total)
# Georgia
# South Asia (IBRD only)
# Denmark
# Post-demographic dividend
# Puerto Rico
# Moldova
# Portugal
# Morocco
# Croatia
# Mongolia
# Guinea-Bissau
# Thailand
# Macedonia, FYR
# Grenada
# Korea, Dem. People's Rep.
# Yemen, Rep.
# Latin America & Caribbean (excluding high income)
# Iraq
# Egypt, Arab Rep.
# Estonia
# Kosovo
# East Asia & Pacific (IDA & IBRD)
# Equatorial Guinea
# Hong Kong SAR, China
# Uzbekistan
# West Bank and Gaza
# Djibouti
# Rwanda
# Antigua and Barbuda
# Low income
# High income
# Burundi
# East Asia & Pacific (IDA total)
# Least developed countries: UN classification
# IDA blend
# Barbados
# Madagascar
# Latin America & Caribbean (IDA total)
# Sub-Saharan Africa (excluding high income)
# Curacao
# Bhutan
# Sudan
# Nepal
# Singapore
# Malta
# Netherlands
# Macao SAR, China
# Suriname
# Kuwait
# Turks and Caicos Islands
# Europe & Central Asia
# Iran, Islamic Rep.
# Israel
# Indonesia
# Malaysia
# Iceland
# Zambia
# Senegal
# Papua New Guinea
# Malawi
# IDA countries not classified as fragile situations
# Trinidad and Tobago
# Zimbabwe
# Germany
# Sub-Saharan Africa (IDA & IBRD)
# Europe & Central Asia (IBRD only)
# East Asia & Pacific (excluding high income)
# Philippines
# Eritrea
# Small states
# Sub-Saharan Africa (IBRD only)
# Mexico
# Sri Lanka
# Not classified
# Latvia
# South Sudan
# Guyana
# IBRD only
# East Asia & Pacific (IDA & IBRD countries)
# Honduras
# Myanmar
# Latin America & Caribbean (IDA & IBRD)
# Tunisia
# Nicaragua
# Faeroe Islands
# Congo, Dem. Rep.
# Serbia
# Comoros
# United Kingdom
# Middle East & North Africa (IDA & IBRD countries)
# Gambia, The
# Sint Maarten (Dutch part)
# Greece
# Paraguay
# Fiji
# Botswana
# Heavily indebted poor countries (HIPC)

# %%
pov_stack.shape
# Out:
# (16588, 25)

# %%
pov_stack.dropna(axis=0, how='all', inplace=True)
pov_stack.dropna(axis=1, how='all', inplace=True)
pov_stack.shape
# Out:
# (2116, 25)

# %%
pov_stack.to_csv('ML_pov_stack.csv')

# %% [markdown]
# # Train Stacks <a class="anchor" id="trainstacks"></a>

# %%
econ_clean = pd.read_csv('ML_data/ML_econ_clean.csv', index_col=0)
fin_clean = pd.read_csv('ML_data/ML_fin_clean.csv', index_col=0)
health_clean = pd.read_csv('ML_data/ML_health_clean.csv', index_col=0)
dev_clean = pd.read_csv('ML_data/ML_dev_clean.csv', index_col=0)
env_clean = pd.read_csv('ML_data/ML_env_clean.csv', index_col=0)
edu_clean = pd.read_csv('ML_data/ML_edu_clean.csv', index_col=0)
pov_clean = pd.read_csv('ML_data/ML_pov_clean.csv', index_col=0)

# %%
fin_clean.columns
# Out:
# Index([u'Automated teller machines (ATMs) (per 100,000 adults)',
#        u'Bank capital to assets ratio (%)',
#        u'Bank liquid reserves to bank assets ratio (%)',
#        u'Bank nonperforming loans to total gross loans (%)',
#        u'Borrowers from commercial banks (per 1,000 adults)',
#        u'Broad money (% of GDP)', u'Broad money (current LCU)',
#        u'Broad money growth (annual %)',
#        u'Broad money to total reserves ratio',
#        u'Claims on central government (annual growth as % of broad money)',
#        u'Claims on central government, etc. (% GDP)',
#        u'Claims on other sectors of the domestic economy (% of GDP)',
#        u'Claims on other sectors of the domestic economy (annual growth as % of broad money)',
#        u'Claims on private sector (annual growth as % of broad money)',
#        u'Commercial bank branches (per 100,000 adults)',
#        u'Consumer price index (2010 = 100)',
#        u'DEC alternative conversion factor (LCU per US$)',
#        u'Deposit interest rate (%)',
#        u'Depositors with commercial banks (per 1,000 adults)',
#        u'Depth of credit information index (0=low to 8=high)',
#        u'Domestic credit provided by financial sector (% of GDP)',
#        u'Domestic credit to private sector (% of GDP)',
#        u'Domestic credit to private sector by banks (% of GDP)',
#        u'Emigration rate of tertiary educated (% of total tertiary educated population)',
#        u'Foreign direct investment, net (BoP, current US$)',
#        u'Foreign direct investment, net inflows (% of GDP)',
#        u'Foreign direct investment, net inflows (BoP, current US$)',
#        u'Foreign direct investment, net outflows (% of GDP)',
#        u'Foreign direct investment, net outflows (BoP, current US$)',
#        u'GDP deflator: linked series (base year varies by country)',
#        u'Inflation, GDP deflator: linked series (annual %)',
#        u'Inflation, consumer prices (annual %)',
#        u'Interest rate spread (lending rate minus deposit rate, %)',
#        u'International migrant stock (% of population)',
#        u'International migrant stock, total', u'Lending interest rate (%)',
#        u'Listed domestic companies, total',
#        u'Market capitalization of listed domestic companies (% of GDP)',
#        u'Market capitalization of listed domestic companies (current US$)',
#        u'Net domestic credit (current LCU)',
#        u'Net foreign assets (current LCU)', u'Net migration',
#        u'Official exchange rate (LCU per US$, period average)',
#        u'Personal remittances, paid (current US$)',
#        u'Personal remittances, received (% of GDP)',
#        u'Personal remittances, received (current US$)',
#        u'Personal transfers, receipts (BoP, current US$)',
#        u'Portfolio equity, net inflows (BoP, current US$)',
#        u'Portfolio investment, bonds (PPG + PNG) (NFL, current US$)',
#        u'Primary income on FDI, payments (current US$)',
#        u'Private credit bureau coverage (% of adults)',
#        u'Public credit registry coverage (% of adults)',
#        u'Real effective exchange rate index (2010 = 100)',
#        u'Real interest rate (%)',
#        u'Risk premium on lending (lending rate minus treasury bill rate, %)',
#        u'S&P Global Equity Indices (annual % change)',
#        u'Stocks traded, total value (% of GDP)',
#        u'Stocks traded, total value (current US$)',
#        u'Stocks traded, turnover ratio of domestic shares (%)',
#        u'Strength of legal rights index (0=weak to 12=strong)',
#        u'Total reserves (% of total external debt)',
#        u'Total reserves (includes gold, current US$)',
#        u'Total reserves in months of imports',
#        u'Total reserves minus gold (current US$)',
#        u'Wholesale price index (2010 = 100)'],
#       dtype='object')

# %%
train_econ = pd.concat([econ_clean, fin_clean, dev_clean, pov_clean], axis=1)

# %%
train_econ.dropna(axis=0, how='all', inplace=True)
train_econ.dropna(axis=1, how='all', inplace=True)
train_econ_stack = get_stack(train_econ)
train_econ_stack.shape
# Out:
# (16994, 459)

# %%
train_econ_stack.dropna(axis=0, how='all', inplace=True)
train_econ_stack.dropna(axis=1, how='all', inplace=True)
train_econ_stack.shape
# Out:
# (15250, 459)

# %%
train_econ_stack.to_csv('ML_train_econ_stack.csv')

# %%
train_econ_stack = make_train_stack([health_clean, fin_clean, dev_clean, pov_clean)

# %%
def make_train_stack(clean_list):
    train_this = pd.concat(clean_list, axis=1)
    print 'step 1'
    train_this.dropna(axis=0, how='all', inplace=True)
    train_this.dropna(axis=1, how='all', inplace=True)
    print 'step 2'
    train_stack = get_stack(train_this)
    print train_stack.shape
    train_stack.dropna(axis=0, how='all', inplace=True)
    train_stack.dropna(axis=1, how='all', inplace=True)
    print train_stack.shape
    
    return train_stack

# %%
train_health_stack = make_train_stack([health_clean, econ_clean, dev_clean])
# Out:
# step 1
# step 2
# (128586, 600)
# (15254, 600)

# %%
train_health_stack.to_csv('ML_train_health_stack.csv')

# %%
1+3

# %%
train_edu_stack = make_train_stack([edu_clean, dev_clean, econ_clean])
train_edu_stack.to_csv('ML_train_edu_stack.csv')
# Out:
# step 1
# step 2
# (16588, 547)
# (15250, 501)

# %%
train_dev_stack = make_train_stack([dev_clean, econ_clean])
train_dev_stack.to_csv('ML_train_dev_stack.csv')
# Out:
# step 1
# step 2
# (16588, 389)
# (15250, 389)

# %%
train_fin_stack = make_train_stack([fin_clean, dev_clean, econ_clean])
train_fin_stack.to_csv('ML_train_fin_stack.csv')
# Out:
# step 1
# step 2
# (16994, 439)
# (15250, 439)

# %%
train_pov_stack = make_train_stack([pov_clean, dev_clean, econ_clean])
train_pov_stack.to_csv('ML_train_pov_stack.csv')
# Out:
# step 1
# step 2
# (16588, 409)
# (15250, 409)

# %%
train_env_stack = make_train_stack([env_clean, dev_clean])
train_env_stack.to_csv('ML_train_env_stack.csv')
# Out:
# step 1
# step 2
# (16588, 172)
# (15250, 172)
